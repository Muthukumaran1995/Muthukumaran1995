# %%
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

# %%
auto = pd.read_csv('E:\INCEPTEZ\Training\Basics_python\Auto_temp.csv',  na_values=['#NAME?'])

# %%
auto.head(5)
# Out:
#    symboling  normalized_losses         make fuel_type aspiration num_doors  \
# 0          3                NaN  alfa-romero       gas        std       two
# 1          3                NaN  alfa-romero       gas        std       two
# 2          1                NaN  alfa-romero       gas        std       two
# 3          2              164.0         audi       gas        std      four
# 4          2              164.0         audi       gas        std      four
#
#     body_style drive_wheels engine_location  wheel_base  ...  engine_size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %% [markdown]
# ### 1. Find the most expensive car company name

# %%
auto[['make','price']][auto.price==auto['price'].max()]
# Out:
#              make    price
# 74  mercedes-benz  45400.0

# %% [markdown]
# ### Count total cars per company

# %%
auto['make'].value_counts()
# Out:
# toyota           32
# nissan           18
# mazda            17
# mitsubishi       13
# honda            13
# volkswagen       12
# subaru           12
# peugot           11
# volvo            11
# dodge             9
# mercedes-benz     8
# bmw               8
# audi              7
# plymouth          7
# saab              6
# porsche           5
# isuzu             4
# jaguar            3
# chevrolet         3
# alfa-romero       3
# renault           2
# mercury           1
# Name: make, dtype: int64

# %% [markdown]
# ### 3. Find each company’s highest price car

# %%
auto.groupby(['make'])['price'].max().reset_index()
# Out:
#              make    price
# 0     alfa-romero  16500.0
# 1            audi  23875.0
# 2             bmw  41315.0
# 3       chevrolet   6575.0
# 4           dodge  12964.0
# 5           honda  12945.0
# 6           isuzu  11048.0
# 7          jaguar  36000.0
# 8           mazda  18344.0
# 9   mercedes-benz  45400.0
# 10        mercury  16503.0
# 11     mitsubishi  14869.0
# 12         nissan  19699.0
# 13         peugot  18150.0
# 14       plymouth  12764.0
# 15        porsche  37028.0
# 16        renault   9895.0
# 17           saab  18620.0
# 18         subaru  11694.0
# 19         toyota  17669.0
# 20     volkswagen  13845.0
# 21          volvo  22625.0

# %% [markdown]
# ### Sort all cars by Price column

# %%
auto[['make','price']].sort_values(by=['price'], ascending=False)
# Out:
#               make    price
# 74   mercedes-benz  45400.0
# 16             bmw  41315.0
# 73   mercedes-benz  40960.0
# 128        porsche  37028.0
# 17             bmw  36880.0
# ..             ...      ...
# 138         subaru   5118.0
# 9             audi      NaN
# 44           isuzu      NaN
# 45           isuzu      NaN
# 129        porsche      NaN
#
# [205 rows x 2 columns]

# %% [markdown]
# ### Group by make, fuel-type and body-style to calculate the average of city-mpg and highwaympg (miles per gallon)

# %%
auto.groupby(['make','fuel_type','body_style']).agg({'city_mpg':'mean','highway_mpg':'mean'})
# Out:
#                                     city_mpg  highway_mpg
# make        fuel_type body_style
# alfa-romero gas       convertible  21.000000    27.000000
#                       hatchback    19.000000    26.000000
# audi        gas       hatchback    16.000000    22.000000
#                       sedan        19.400000    24.400000
#                       wagon        19.000000    25.000000
# ...                                      ...          ...
# volkswagen  gas       sedan        25.200000    31.600000
#                       wagon        25.000000    31.000000
# volvo       diesel    sedan        26.000000    27.000000
#             gas       sedan        20.428571    25.571429
#                       wagon        21.333333    26.000000
#
# [66 rows x 2 columns]
